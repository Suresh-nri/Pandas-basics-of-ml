# %% [markdown]
# Importing Pandas and as well as required Files from the Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %% [markdown]
# Reading CSV file for the Pandas Commands

# %%
ds=pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications.csv')

# %% [markdown]
# Displaying the CSV File

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(70):
 age.append(random.randint(0,70))
 weight.append(random.randint(0,70))
 height.append(random.randint(0,70))
 speed.append(random.randint(0,70))
idata = {'Age':age,'height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [45,
#   19,
#   35,
#   6,
#   27,
#   18,
#   42,
#   27,
#   0,
#   45,
#   42,
#   68,
#   18,
#   54,
#   70,
#   21,
#   70,
#   35,
#   38,
#   68,
#   39,
#   62,
#   2,
#   28,
#   59,
#   67,
#   26,
#   48,
#   13,
#   70,
#   53,
#   43,
#   41,
#   24,
#   36,
#   14,
#   24,
#   20,
#   45,
#   48,
#   49,
#   48,
#   51,
#   37,
#   27,
#   7,
#   17,
#   11,
#   54,
#   66,
#   9,
#   70,
#   16,
#   53,
#   1,
#   10,
#   47,
#   19,
#   6,
#   6,
#   63,
#   14,
#   40,
#   47,
#   60,
#   34,
#   7,
#   14,
#   19,
#   0],
#  'height': [70,
#   58,
#   49,
#   21,
#   31,
#   36,
#   2,
#   60,
#   57,
#   57,
#   61,
#   20,
#   2,
#   13,
#   63,
#   33,
#   69,
#   47,
#   4,
#   64,
#   25,
#   48,
#   38,
#   58,
#   44,
#   5,
#   64,
#   13,
#   16,
#   35,
#   66,
#   48,
#   20,
#   52,
#   10,
#   69,
#   35,
#   9,
#   41,
#   68,
#   47,
#   37,
#   38,
#   43,
#   3,
#   22,
#   36,
#   69,
#   14,
#   62,
#   52,
#   32,
#   52,
#   31,
#   3,
#   47,
#   16,
#   28,
#   5,
#   48,
#   35,
#   11,
#   68,
#   9,
#   58,
#   60,
#   24,
#   65,
#   32,
#   50],
#  'Weight': [33,
#   32,
#   1,
#   53,
#   12,
#   64,
#   56,
#   48,
#   42,
#   28,
#   16,
#   19,
#   12,
#   51,
#   47,
#   27,
#   60,
#   55,
#   28,
#   59,
#   30,
#   33,
#   35,
#   31,
#   32,
#   62,
#   39,
#   37,
#   41,
#   57,
#   23,
#   44,
#   41,
#   15,
#   67,
#   25,
#   28,
#   46,
#   29,
#   20,
#   4,
#   44,
#   1,
#   41,
#   3,
#   57,
#   62,
#   10,
#   58,
#   63,
#   28,
#   5,
#   16,
#   7,
#   33,
#   18,
#   29,
#   23,
#   7,
#   42,
#   32,
#   50,
#   15,
#   9,
#   4,
#   10,
#   66,
#   11,
#   2,
#   14],
#  'Speed': [60,
#   36,
#   39,
#   50,
#   6,
#   47,
#   19,
#   4,
#   14,
#   29,
#   21,
#   56,
#   65,
#   69,
#   30,
#   22,
#   35,
#   7,
#   13,
#   60,
#   41,
#   42,
#   32,
#   14,
#   64,
#   67,
#   0,
#   1,
#   35,
#   6,
#   34,
#   56,
#   49,
#   44,
#   57,
#   40,
#   20,
#   42,
#   46,
#   28,
#   55,
#   24,
#   24,
#   34,
#   18,
#   37,
#   19,
#   14,
#   65,
#   54,
#   42,
#   39,
#   46,
#   69,
#   18,
#   26,
#   21,
#   32,
#   43,
#   64,
#   15,
#   68,
#   39,
#   42,
#   27,
#   41,
#   14,
#   39,
#   14,
#   30]}

# %% [markdown]
# Converting Dictionary into DataFrames

# %%
df=pd.DataFrame(idata)

# %%
df
# Out:
#     Age  height  Weight  Speed
# 0    45      70      33     60
# 1    19      58      32     36
# 2    35      49       1     39
# 3     6      21      53     50
# 4    27      31      12      6
# ..  ...     ...     ...    ...
# 65   34      60      10     41
# 66    7      24      66     14
# 67   14      65      11     39
# 68   19      32       2     14
# 69    0      50      14     30
#
# [70 rows x 4 columns]

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]

# %% [markdown]
# Tail()-read and display values from the end

# %%
df.tail(10)
# Out:
#     Age  height  Weight  Speed
# 60   63      35      32     15
# 61   14      11      50     68
# 62   40      68      15     39
# 63   47       9       9     42
# 64   60      58       4     27
# 65   34      60      10     41
# 66    7      24      66     14
# 67   14      65      11     39
# 68   19      32       2     14
# 69    0      50      14     30

# %% [markdown]
# Head() - read and display values from the beginning

# %%
df.head(10)
# Out:
#    Age  height  Weight  Speed
# 0   45      70      33     60
# 1   19      58      32     36
# 2   35      49       1     39
# 3    6      21      53     50
# 4   27      31      12      6
# 5   18      36      64     47
# 6   42       2      56     19
# 7   27      60      48      4
# 8    0      57      42     14
# 9   45      57      28     29

# %%
df.iloc[0]
# Out:
# Age       45
# height    70
# Weight    33
# Speed     60
# Name: 0, dtype: int64

# %%
df.iloc[[0,1,2]]
# Out:
#    Age  height  Weight  Speed
# 0   45      70      33     60
# 1   19      58      32     36
# 2   35      49       1     39

# %%
df.iloc[[1,3,4],[2,3,1]]
# Out:
#    Weight  Speed  height
# 1      32     36      58
# 3      53     50      21
# 4      12      6      31

# %%
df.iloc[[1],[1,2,3]]
# Out:
#    height  Weight  Speed
# 1      58      32     36

# %%
df.loc[[0,2],['Age','Weight']]
# Out:
#    Age  Weight
# 0   45      33
# 2   35       1

# %%
df.loc[1,"Age"]
# Out:
# 19

# %%
df.loc[[1,2,3],"Age"]
# Out:
# 1    19
# 2    35
# 3     6
# Name: Age, dtype: int64

# %%
#slicing using the loc
df.loc[1:3,"Age":"Speed"]
# Out:
#    Age  height  Weight  Speed
# 1   19      58      32     36
# 2   35      49       1     39
# 3    6      21      53     50

# %%
df.loc[1:3:2,"Age":"Weight":2]
# Out:
#    Age  Weight
# 1   19      32
# 3    6      53

# %%
df.loc[1:4]
# Out:
#    Age  height  Weight  Speed
# 1   19      58      32     36
# 2   35      49       1     39
# 3    6      21      53     50
# 4   27      31      12      6

# %%
#slicing the rows
ds.loc[1:3]
# Out:
#    CustomerID  A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 1    15739548   0  22.67   7.00   2   8   4  0.165   0   0    0    0    2
# 2    15662854   0  29.58   1.75   1   4   4  1.250   0   0    0    1    2
# 3    15687688   0  21.67  11.50   1   5   3  0.000   1   1   11    1    2
#
#    A13  A14  Class
# 1  160    1      0
# 2  280    1      0
# 3    0    1      1

# %%
df.loc[1:5:2]
# Out:
#    Age  height  Weight  Speed
# 1   19      58      32     36
# 3    6      21      53     50
# 5   18      36      64     47

# %%
#slicing the columns
df.loc[0:1]
# Out:
#    Age  height  Weight  Speed
# 0   45      70      33     60
# 1   19      58      32     36

# %%
df.loc[0:1,"height":"Speed":2]
# Out:
#    height  Speed
# 0      70     60
# 1      58     36

# %%
#Set an index using : ds.set_index('column_name',inplace=True)
#Inplace=true}makes the dataset permanent
df.set_index("Speed",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-e8caae179f75> in <cell line: 0>()
#       1 #Set an index using : ds.set_index('column_name',inplace=True)
#       2 #Inplace=true}makes the dataset permanent
# ----> 3 df.set_index("Speed",inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Speed'] are in the columns"

# %% [markdown]
# Here Close is the index for this present Dataset

# %%
df
# Out:
#        Age
# Speed
# 60      45
# 36      19
# 39      35
# 50       6
# 6       27
# ...    ...
# 41      34
# 14       7
# 39      14
# 14      19
# 30       0
#
# [70 rows x 1 columns]

# %% [markdown]
# Reset index using : reset_index(inplace=True)

# %%
df.reset_index(inplace=True)

# %% [markdown]
# Now the "Close" label is not index anymore

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [45, 19, 35, 6, 27, 18, 42, 27, 0, 45, 42, 68, 18, 54, 70, 21, 70, 35, 38, 68, 39, 62, 2, 28, 59, 67, 26, 48, 13, 70, 53, 43, 41, 24, 36, 14, 24, 20, 45, 48, 49, 48, 51, 37, 27, 7, 17, 11, 54, 66, 9, 70, 16, 53, 1, 10, 47, 19, 6, 6, 63, 14, 40, 47, 60, 34, 7, 14, 19, 0]
#
# [70 rows x 0 columns]

# %% [markdown]
# Queries Usage after "set_index".
#      Setting close as index

# %%
df.set_index("Age",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-756052946a03> in <cell line: 0>()
# ----> 1 df.set_index("Age",inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Age'] are in the columns"

# %% [markdown]
# read row with index of close at "66"

# %%
df.loc[34]
# Out:
# Series([], Name: 34, dtype: float64)

# %% [markdown]
# Sort using Filter
#
# Sorting the dataset using >>>        :::sort_index(ascending=True/False,inplace=True)Sort using Filter

# %%
df
# Out:
#         Age  Weight  Speed
# height
# 70       45      33     60
# 58       19      32     36
# 49       35       1     39
# 21        6      53     50
# 31       27      12      6
# ...     ...     ...    ...
# 60       34      10     41
# 24        7      66     14
# 65       14      11     39
# 32       19       2     14
# 50        0      14     30
#
# [70 rows x 3 columns]

# %% [markdown]
# deafult sort for ascending value is True

# %%
df.sort_index()
# Out:
#         Age  Weight  Speed
# height
# 2        18      12     65
# 2        42      56     19
# 3        27       3     18
# 3         1      33     18
# 4        38      28     13
# ...     ...     ...    ...
# 68       48      20     28
# 69       11      10     14
# 69       14      25     40
# 69       70      60     35
# 70       45      33     60
#
# [70 rows x 3 columns]

# %% [markdown]
# Reverse the sort

# %%
df.sort_index(ascending=False)
# Out:
#         Age  Weight  Speed
# height
# 70       45      33     60
# 69       70      60     35
# 69       11      10     14
# 69       14      25     40
# 68       40      15     39
# ...     ...     ...    ...
# 4        38      28     13
# 3         1      33     18
# 3        27       3     18
# 2        18      12     65
# 2        42      56     19
#
# [70 rows x 3 columns]
